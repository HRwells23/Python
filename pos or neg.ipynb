# %%
value =  float(input("Enter the no.  " ) )
# Out:
# Enter the no.  0

# %%
if value < 0:
    print ("Negative")
if value > 0:
    print ("Positive")
if value == 0:
    print ("Zero")
# Out:
# Zero
